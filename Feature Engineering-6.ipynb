# %%
### Q1. Pearson correlation coefficient is a measure of the linear relationship between two variables. Suppose  you have collected data on the amount of time students spend studying for an exam and their final exam scores. Calculate the Pearson correlation coefficient between these two variables and interpret the result.





import pandas as pd
import numpy as np

# Create a sample dataset
data = {'Study Time': [2, 4, 6, 8, 10], 
        'Exam Score': [70, 80, 90, 95, 100]}
df = pd.DataFrame(data)

# Calculate the Pearson correlation coefficient
correlation_coefficient = df['Study Time'].corr(df['Exam Score'])
print(correlation_coefficient)
# Out:
# 0.9847982464479191

# %%
### Q2. Spearman's rank correlation is a measure of the monotonic relationship between two variables. Suppose you have collected data on the amount of sleep individuals get each night and their overall job satisfaction level on a scale of 1 to 10. Calculate the Spearman's rank correlation between these two variables and interpret the result.

import pandas as pd
from scipy.stats import spearmanr
import matplotlib.pyplot as plt

# Create a sample dataset
data = {'Sleep Hours': [7, 6, 8, 5, 9, 7, 6, 8, 5, 9], 
        'Job Satisfaction': [8, 7, 9, 6, 10, 8, 7, 9, 6, 10]}
df = pd.DataFrame(data)

# Calculate Spearman's rank correlation
spearman_corr, p_value = spearmanr(df['Sleep Hours'], df['Job Satisfaction'])
print(f'Spearman\'s rank correlation: {spearman_corr}')
print(f'p-value: {p_value}')

# Visualize the data
plt.figure(figsize=(10, 6))
plt.scatter(df['Sleep Hours'], df['Job Satisfaction'])
plt.xlabel('Sleep Hours')
plt.ylabel('Job Satisfaction')
plt.title('Spearman\'s Rank Correlation')
plt.show()
# Out:
# Spearman's rank correlation: 1.0
# p-value: 0.0

# %%
#### Q3. Suppose you are conducting a study to examine the relationship between the number of hours of exercise per week and body mass index (BMI) in a sample of adults. You collected data on both variables  for 50 participants. Calculate the Pearson correlation coefficient and the Spearman's rank correlation between these two variables and compare the results.

import pandas as pd
import numpy as np
from scipy.stats import pearsonr, spearmanr

# Create a sample dataset
np.random.seed(0)
data = {'Exercise Hours': np.random.normal(5, 2, 50), 
        'BMI': np.random.normal(25, 5, 50)}
df = pd.DataFrame(data)

# Calculate Pearson correlation coefficient
pearson_corr, pearson_p_value = pearsonr(df['Exercise Hours'], df['BMI'])
print(f'Pearson correlation coefficient: {pearson_corr}')
print(f'p-value: {pearson_p_value}')

# Calculate Spearman's rank correlation
spearman_corr, spearman_p_value = spearmanr(df['Exercise Hours'], df['BMI'])
print(f'Spearman\'s rank correlation: {spearman_corr}')
print(f'p-value: {spearman_p_value}')

# Visualize the data
import matplotlib.pyplot as plt

#plt.figure(figsize=(10, 6))
#plt.scatter(df['Exercise Hours'], df['BMI'])
#plt.xlabel('Exercise Hours')
#plt.ylabel('BMI')
#plt.title('Correlation between Exercise Hours and BMI')
#plt.show()


#This code snippet performs the following tasks:

#1. Creates a sample dataset with Exercise Hours and BMI columns
#2. Calculates Pearson correlation coefficient using pearsonr() function from scipy.stats module
#3. Calculates Spearman's rank correlation using spearmanr() function from scipy.stats module
#4. Prints the correlation coefficient values and p-values for both Pearson and Spearman correlations
#5. Visualizes the data using a scatter plot to illustrate the relationship
# Out:
# Pearson correlation coefficient: -0.05918059495215542
# p-value: 0.6830946622054956
# Spearman's rank correlation: -0.07418967587034814
# p-value: 0.6086242993514357

# %%
### Q4. A researcher is interested in examining the relationship between the number of hours individuals spend watching television per day and their level of physical activity. The researcher collected data on

#both variables from a sample of 50 participants. Calculate the Pearson correlation coefficient between
#these two variables.

import pandas as pd
import numpy as np
from scipy.stats import pearsonr

# Create a sample dataset
np.random.seed(0)
data = {'TV Hours': np.random.normal(3, 1.5, 50), 
        'Physical Activity': np.random.normal(5, 2, 50)}
df = pd.DataFrame(data)

# Calculate Pearson correlation coefficient
pearson_corr, pearson_p_value = pearsonr(df['TV Hours'], df['Physical Activity'])
print(f'Pearson correlation coefficient: {pearson_corr}')
print(f'p-value: {pearson_p_value}')

# Visualize the data
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.scatter(df['TV Hours'], df['Physical Activity'])
plt.xlabel('TV Hours')
plt.ylabel('Physical Activity')
plt.title('Correlation between TV Hours and Physical Activity')
plt.show()
# Out:
# Pearson correlation coefficient: -0.05918059495215547
# p-value: 0.6830946622054956

# %%
### Q6. A company is interested in examining the relationship between the number of sales calls made per day
#and the number of sales made per week. The company collected data on both variables from a sample of
#30 sales representatives. Calculate the Pearson correlation coefficient between these two variables.
